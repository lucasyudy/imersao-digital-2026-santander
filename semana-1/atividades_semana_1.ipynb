# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasyudy/imersao-digital-2026-santander/blob/main/semana-1/atividades_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Célula 1 (Markdown):
  Título: "📚 Semana 1 — Imersão Digital 2026"
  Subtítulo: "Notas de estudo — Lucas Yudy Okuda"

---

Célula 2 (Markdown):
  "## 🖥️ Curso: Pensamento Computacional"

Célula 3 (Código - Python):
  # Desafio: Calculadora de Pedidos (Cafeteria)
  preco_hamburguer = 12
  preco_batata = 7
  preco_refri = 5
  qtd_hamburguer = 2
  qtd_batata = 1
  qtd_refri = 2
  total_pedido = (qtd_hamburguer * preco_hamburguer) + (qtd_batata * preco_batata) + (qtd_refri * preco_refri)
  print(f"Total do pedido: R$ {total_pedido}")

Célula 4 (Markdown):
  "## 🤖 Curso: IA Generativa"

Célula 5 (Markdown):
  "### Prompts utilizados:"

Célula 6 (Markdown):
  "Prompt 1 — Blog de alimentação saudável:"
  """Insira seu prompt do ChatGPT aqui..."""

---

Célula final (Markdown):
  "## 🔗 Links"
  "- [Curso: Pensamento Computacional](https://...)"
  "- [Curso: IA Generativa](https://...)"
