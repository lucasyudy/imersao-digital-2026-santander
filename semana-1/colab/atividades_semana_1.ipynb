# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasyudy/imersao-digital-2026-santander/blob/main/semana-1/colab/atividades_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓 Semana 1 — Imersão Digital 2026
# ## Notas de estudo — Lucas Yudy Okuda
#
# **Bolsa oferecida por:** Santander Open Academy + Alura
# **Semana:** 1 | **Status:** ✅ Concluída | **Carga horária:** 16h (8h + 8h)
#
# ---

# %% [markdown]
# ## 🖥️ Curso 1: Pensamento Computacional
# **⏱️ 8h** | **📊 Avaliação: 9,4** | **🎯 100% concluído**

# %% [markdown]
# ## Desafio: organizando o suporte ao cliente
#
# Você foi contratado como analista em uma empresa de tecnologia e recebeu a seguinte demanda do time de Customer Success:
# #
# *“Precisamos melhorar a forma como lidamos com os pedidos de suporte dos usuários. As mensagens chegam com vários problemas misturados, como dificuldades para acessar o sistema, dúvidas sobre pagamento ou erros no uso de funcionalidades. Está tudo confuso e difícil de responder de forma ágil.”*
# #
# Utilizando os fundamentos do pensamento computacional, a proposta é organizar e automatizar o atendimento por meio de categorização, identificação de padrões, abstração do fluxo e definição de um algoritmo simples de resposta.
#
# ### Resposta
# #
# Para resolver esse problema, o primeiro passo é aplicar a **decomposição**, separando os atendimentos em categorias principais, como:
# - acesso ao sistema;
# - pagamento;
# - uso da plataforma.
# #
# Essa divisão facilita a organização do suporte e permite tratar cada tipo de solicitação de forma mais objetiva.
# #
# Em seguida, é possível aplicar o reconhecimento de **padrões**, observando que muitas dúvidas se repetem dentro de cada categoria. Por exemplo, em acesso ao sistema podem aparecer com frequência problemas de senha, em pagamento, dúvidas sobre cobrança, e em uso da plataforma, dificuldades para localizar funcionalidades.
# #
# A próxima etapa é a **abstração**, criando modelos simplificados para o atendimento, como respostas padrão, perguntas frequentes (FAQ) e formulários com opções pré-definidas. Assim, em vez de analisar cada mensagem do zero, o time trabalha com uma estrutura mais clara e padronizada.
# #
# Por fim, é viável construir um **algoritmo** para lidar com cada solicitação. Esse fluxo pode seguir a sequência:
# #
# **Receber mensagem → Identificar categoria → Verificar se existe resposta padrão → Enviar resposta automática ou encaminhar para o setor responsável**.
# #
# Dessa forma, o atendimento se torna mais rápido, organizado e eficiente, reduzindo o tempo de resposta e melhorando a experiência do usuário.
#
# ### Exemplo de algoritmo em pseudocódigo
# #
# ```
# Início
# Receber mensagem do usuário
# Identificar categoria da solicitação
# Se categoria tiver resposta padrão:
#     enviar resposta automática
# Senão:
#     encaminhar para o setor responsável
# Fim
# ```

# %%
# Exemplo simples em Python inspirado na solução do desafio

def classificar_solicitacao(mensagem):
    mensagem = mensagem.lower()

    if "senha" in mensagem or "login" in mensagem or "acesso" in mensagem:
        return "acesso"
    elif "pagamento" in mensagem or "cobrança" in mensagem or "boleto" in mensagem:
        return "pagamento"
    elif "erro" in mensagem or "funcionalidade" in mensagem or "plataforma" in mensagem:
        return "uso da plataforma"
    else:
        return "outros"

def responder_suporte(mensagem):
    categoria = classificar_solicitacao(mensagem)

    respostas = {
        "acesso": "Resposta automática: orientações para redefinição de senha e recuperação de acesso.",
        "pagamento": "Resposta automática: informações sobre cobrança, boleto e confirmação de pagamento.",
        "uso da plataforma": "Resposta automática: passo a passo de uso da funcionalidade informada."
    }

    if categoria in respostas:
        return f"Categoria: {categoria}\n{respostas[categoria]}"
    else:
        return f"Categoria: {categoria}\nEncaminhar para atendimento humano."

mensagem_teste = "Não consigo fazer login na plataforma porque esqueci minha senha."
print(responder_suporte(mensagem_teste))
# Out:
# Categoria: acesso
# Resposta automática: orientações para redefinição de senha e recuperação de acesso.

# %% [markdown]
# ## Desafio: automatizando processos na equipe de RH
# #
# Você está atuando como analista em um projeto com o time de Recursos Humanos de uma empresa.
# A equipe está sobrecarregada porque precisa, toda semana, organizar entrevistas com candidatos,
# enviar e-mails de confirmação e montar uma agenda com todos os horários.
# #
# *“Estamos gastando muito tempo com tarefas repetitivas. Será que dá pra facilitar esse processo?”*
# #
# Utilizando a abordagem de pensamento computacional, a proposta é organizar esse fluxo
# para reduzir o esforço manual e tornar o processo mais ágil.
#
# ### Resposta
# #
# Para resolver esse problema, o primeiro passo é aplicar a **decomposição do processo**,
# dividindo a tarefa principal de organizar entrevistas em etapas menores, como:
# - coletar a disponibilidade dos candidatos;
# - enviar os convites;
# - receber as confirmações;
# - montar a agenda final.
# #
# Essa divisão facilita a visualização do fluxo, ajuda a identificar gargalos
# e mostra com clareza quais atividades são repetitivas e podem ser automatizadas.
# #
# Em seguida, é importante observar os **padrões**. O processo de entrevista costuma seguir
# sempre a mesma sequência: primeiro acontece o contato com o candidato, depois a resposta,
# em seguida a confirmação do horário e, por fim, a reserva da agenda. Reconhecer esse padrão
# permite criar soluções reutilizáveis e padronizadas para o RH.
# #
# Ao aplicar a **abstração**, podemos representar todo esse conjunto de etapas como um único fluxo
# automatizado, utilizando por exemplo uma ferramenta de agendamento. Nesse modelo, o candidato
# recebe um e-mail com link para escolher o horário disponível, e o sistema registra a escolha
# em um calendário compartilhado, escondendo a complexidade operacional do processo.
# #
# Por fim, podemos definir um **algoritmo** para automatizar o fluxo:
# **Receber a lista de candidatos → Enviar e-mail com link de agendamento → Confirmar horário escolhido → Atualizar agenda da equipe → Enviar lembrete automático antes da entrevista**.
# #
# Dessa forma, o trabalho do RH se torna mais organizado, rápido e escalável,
# reduzindo tarefas manuais e melhorando a experiência tanto da equipe quanto dos candidatos.

# %% [markdown]
# ### Exemplo de algoritmo em pseudocódigo
# #
#
# ```
# Início
# Receber lista de candidatos
# Para cada candidato:
#     enviar e-mail com link de agendamento
#     aguardar escolha do horário
#     confirmar entrevista
#     atualizar agenda da equipe
#     enviar lembrete automático
# Fim
# ```

# %%
# Exemplo simples em Python inspirado na solução do desafio

candidatos = [
    {"nome": "Ana", "email": "ana@email.com", "horario": "10:00"},
    {"nome": "Bruno", "email": "bruno@email.com", "horario": "14:00"},
    {"nome": "Carla", "email": "carla@email.com", "horario": "16:00"}
]

def processar_entrevistas(lista_candidatos):
    agenda = []

    for candidato in lista_candidatos:
        nome = candidato["nome"]
        email = candidato["email"]
        horario = candidato["horario"]

        print(f"Enviando e-mail de agendamento para {nome} ({email})...")
        print(f"Horário confirmado: {horario}")
        print(f"Atualizando agenda da equipe com a entrevista de {nome}...")
        print(f"Enviando lembrete automático para {nome}...\n")

        agenda.append({"nome": nome, "horario": horario})

    return agenda

agenda_final = processar_entrevistas(candidatos)
agenda_final
# Out:
# Enviando e-mail de agendamento para Ana (ana@email.com)...
# Horário confirmado: 10:00
# Atualizando agenda da equipe com a entrevista de Ana...
# Enviando lembrete automático para Ana...
#
# Enviando e-mail de agendamento para Bruno (bruno@email.com)...
# Horário confirmado: 14:00
# Atualizando agenda da equipe com a entrevista de Bruno...
# Enviando lembrete automático para Bruno...
#
# Enviando e-mail de agendamento para Carla (carla@email.com)...
# Horário confirmado: 16:00
# Atualizando agenda da equipe com a entrevista de Carla...
# Enviando lembrete automático para Carla...
# [{'nome': 'Ana', 'horario': '10:00'},
#  {'nome': 'Bruno', 'horario': '14:00'},
#  {'nome': 'Carla', 'horario': '16:00'}]

# %% [markdown]
# ### Conclusão
# #
# A aplicação do pensamento computacional permite organizar o processo de entrevistas de forma lógica,
# identificando etapas, padrões e oportunidades de automação. Com isso, o time de RH reduz o trabalho
# manual, ganha produtividade e torna o fluxo de entrevistas mais eficiente e escalável.

# %% [markdown]
# ## Desafio: Automatizando tarefas
# #
# Você está trabalhando como pessoa desenvolvedora júnior em uma equipe que está criando
# um sistema para auxiliar no controle de presença em eventos online. O time precisa de um
# algoritmo que processe a lista de participantes e envie um e-mail de agradecimento
# apenas para quem participou de toda a transmissão ao vivo.
# #
# > “Queremos automatizar o envio de agradecimentos. Mas só para quem assistiu à transmissão
# > do início ao fim. Você consegue organizar esse processo em um algoritmo?”
# #
#
# ### Solução
# #
# **1. Dados de entrada necessários**
# - Lista de participantes do evento.
# - Para cada participante: horário de entrada e horário de saída na transmissão.
# - Duração total do evento (em minutos, por exemplo) .
# #
# **2. Verificação da presença completa**
# - Para cada participante, calcular o tempo assistido:
# `tempo_assistido = horário_de_saída - horário_de_entrada.`
# - Comparar esse tempo com a duração total da transmissão .
# #
# **3. Decisão com base nos dados**
# - Se o tempo assistido for igual ou maior que o tempo total do evento, o participante
# será considerado como tendo participado de toda a transmissão .
# - Caso contrário, ele não se enquadra no critério de presença completa.
# #
# **4. Ação final**
# - Para cada participante com presença completa, enviar um e-mail de agradecimento.
# - Para os demais, não enviar o e-mail .
# #
# **Algoritmo (passo a passo)**
# 1. Receber a lista de participantes com horários de entrada e saída.
# 2. Para cada participante da lista:
#     a. Calcular o tempo assistido (saída - entrada).
#     b. Verificar se o tempo assistido é igual ou maior que a duração total do evento.
#     c. Se for, marcar o participante para receber o e-mail de agradecimento.
#     d. Senão, não marcar para envio.
# 3. Enviar os e-mails de agradecimento para todos os participantes marcados.

# %% [markdown]
# ### Exemplo de algoritmo em pseudocódigo
#
# ```
# Início
#   receber duração_total_evento
#   receber lista_participantes (com horário_entrada e horário_saida)
#   para cada participante em lista_participantes:
#       calcular tempo_assistido = horário_saida - horário_entrada
#       se tempo_assistido >= duração_total_evento:
#           marcar para envio de e-mail de agradecimento
#       senão:
#           não enviar e-mail
#   enviar e-mails para todos os participantes marcados
# Fim
# ```

# %%
# Exemplo simples em Python inspirado no algoritmo descrito

participantes = [
    {"nome": "Ana",   "entrada": 0,   "saida": 60},
    {"nome": "Bruno", "entrada": 5,   "saida": 40},
    {"nome": "Carla", "entrada": 0,   "saida": 60},
]

duracao_total_evento = 60  # em minutos

def participantes_com_presenca_completa(lista, duracao_total):
    aptos = []

    for p in lista:
        tempo_assistido = p["saida"] - p["entrada"]

        if tempo_assistido >= duracao_total:
            aptos.append(p["nome"])

    return aptos

aptos_para_agradecimento = participantes_com_presenca_completa(
    participantes,
    duracao_total_evento
)

print("Participantes com presença completa:")
for nome in aptos_para_agradecimento:
    print(f"- {nome}")

# Aqui, em um sistema real, entraria a lógica de envio de e-mail
# para cada participante listado acima.
# Out:
# Participantes com presença completa:
# - Ana
# - Carla

# %% [markdown]
# ### Comentário final sobre o desafio
# #
# Esse desafio mostra como um problema do mundo real, enviar e-mails apenas para quem
# participou de toda a transmissão pode ser convertido em um algoritmo claro e executável.
# A partir da definição dos dados de entrada, da verificação da condição de presença completa
# e da decisão de envio ou não de e-mail, fica evidente como a lógica de programação ajuda
# a automatizar tarefas repetitivas e a reduzir o trabalho manual.

# %% [markdown]
# ## Desafio: Classificando desempenho acadêmico
# #
# Você está trabalhando no desenvolvimento de um sistema educacional que precisa exibir
# mensagens personalizadas para estudantes com base em sua média final.
# #
# A regra definida pela equipe pedagógica é:
#  - Média menor que 5,0: mensagem **"Você está reprovado."**
#  - Média entre 5,0 e 6,9: mensagem **"Você está de recuperação."**
#  - Média 7,0 ou mais: mensagem **"Parabéns! Você foi aprovado."**
# #
# Sua tarefa é criar um algoritmo em **linguagem natural** que represente esse processo de
# verificação e decisão, usando **estruturas condicionais**.

# %% [markdown]
# ### Solução
# #
#  1. Solicitar a média final do estudante.
#  2. Verificar o valor da média usando condições encadeadas:
#     - Se a média for menor que 5,0:
#       - Exibir a mensagem: **"Você está reprovado."**
#     - Senão, se a média for menor que 7,0:
#       - Exibir a mensagem: **"Você está de recuperação."**
#     - Senão:
#       - Exibir a mensagem: **"Parabéns! Você foi aprovado."**
# #
# Essa estrutura garante que apenas uma mensagem será exibida para cada estudante,
# de forma clara e objetiva.

# %% [markdown]
# ### Exemplo de algoritmo em pseudocódigo
#
# ```
# Início
#   ler média_final
#   se média_final < 5,0 então
#       exibir "Você está reprovado."
#   senão se média_final < 7,0 então
#       exibir "Você está de recuperação."
#   senão
#       exibir "Parabéns! Você foi aprovado."
# Fim
# ```

# %%
# Exemplo em Python inspirado no algoritmo do desafio

media = float(input("Informe a média final do estudante: "))

if media < 5.0:
    mensagem = "Você está reprovado."
elif media < 7.0:
    mensagem = "Você está de recuperação."
else:
    mensagem = "Parabéns! Você foi aprovado."

print(mensagem)
# Out:
# Informe a média final do estudante: 6
# Você está de recuperação.

# %% [markdown]
# ### Comentário sobre o desafio
# #
# Esse desafio mostra o uso direto de **estruturas condicionais encadeadas** para traduzir
# regras de negócio em lógica de decisão: a partir de uma única entrada (a média final),
# o sistema escolhe exatamente uma entre três mensagens possíveis, sem ambiguidades.
# Esse padrão é comum em sistemas educacionais, financeiros e de recomendação, onde faixas
# de valores determinam respostas específicas.

# %% [markdown]
# ## Desafio: Calculando pedidos
# #
# Você está desenvolvendo uma funcionalidade para um aplicativo de lanchonete.
# O sistema precisa calcular o valor total de um pedido com base na quantidade de itens solicitados.
# #
# Itens disponíveis:
#  - Hambúrguer: R$ 12,00
#
#  - Batata frita: R$ 7,00
#
#  - Refrigerante: R$ 5,00
# #
# Sua tarefa é criar um algoritmo em linguagem natural (ou fluxograma) que:
#  - armazene os preços e quantidades em variáveis;
#  - calcule o valor total do pedido com base nas quantidades informadas.

# %% [markdown]
# ### Solução
# #
# 1. Criar variáveis para armazenar os preços fixos dos itens:
#    - `preco_hamburguer = 12`
#    - `preco_batata = 7`
#    - `preco_refri = 5`
# #
# 2. Criar variáveis para guardar as quantidades que o cliente informar:
#    - `qtd_hamburguer`
#    - `qtd_batata`
#    - `qtd_refri`
# #
# 3. Calcular o subtotal de cada item:
#    - `total_hamburguer = qtd_hamburguer * preco_hamburguer`
#    - `total_batata = qtd_batata * preco_batata`
#    - `total_refri = qtd_refri * preco_refri`.
# #
# 4. Calcular o valor total do pedido somando os subtotais:
#    - `total_pedido = total_hamburguer + total_batata + total_refri`.
# #
# 5. Exibir uma mensagem clara para o cliente informando o valor total a pagar.

# %% [markdown]
# ### Algoritmo em pseudocódigo
#
# ```
# Início
#   preco_hamburguer ← 12
#   preco_batata ← 7
#   preco_refri ← 5
#   ler qtd_hamburguer
#   ler qtd_batata
#   ler qtd_refri
#   total_hamburguer ← qtd_hamburguer * preco_hamburguer
#   total_batata ← qtd_batata * preco_batata
#   total_refri ← qtd_refri * preco_refri
#   total_pedido ← total_hamburguer + total_batata + total_refri
#   exibir "Valor total do pedido: R$", total_pedido
# # Fim
# ```

# %%
# Exemplo em Python inspirado no algoritmo do desafio

preco_hamburguer = 12.00
preco_batata = 7.00
preco_refri = 5.00

qtd_hamburguer = int(input("Quantidade de hambúrgueres: "))
qtd_batata = int(input("Quantidade de batatas fritas: "))
qtd_refri = int(input("Quantidade de refrigerantes: "))

total_hamburguer = qtd_hamburguer * preco_hamburguer
total_batata = qtd_batata * preco_batata
total_refri = qtd_refri * preco_refri

total_pedido = total_hamburguer + total_batata + total_refri

print(f"Valor total do pedido: R$ {total_pedido:.2f}")
# Out:
# Quantidade de hambúrgueres: 2
# Quantidade de batatas fritas: 2
# Quantidade de refrigerantes: 2
# Valor total do pedido: R$ 48.00

# %% [markdown]
# ### Comentário sobre o desafio
# #
# Esse desafio trabalha diretamente com **variáveis numéricas** e operações de multiplicação
# e soma, exatamente como é comum em sistemas de pedidos reais. Ao separar preços,
# quantidades e subtotais em variáveis, o algoritmo fica mais organizado e fácil de manter,
# além de deixar clara a relação entre os dados e o cálculo final apresentado ao cliente.

# %% [markdown]
# ## Desafio: Verificação de desconto
# #
# Você está desenvolvendo o sistema de bilheteria para um cinema. Os clientes podem ter
# direito a meia-entrada em duas situações :
# - Se tiverem menos de 18 anos; **ou**
# - Se forem estudantes.
# #
# Sua tarefa é criar um algoritmo em linguagem natural (ou fluxograma) que avalie as
# informações do cliente e exiba uma mensagem indicando se ele tem ou não direito ao desconto,
# usando expressões lógicas com operador **OU** .

# %% [markdown]
# ### Solução
# #
# 1. Solicitar a idade do cliente.
# 2. Perguntar se o cliente é estudante (pode ser respondido como sim/não ou verdadeiro/falso) .
# 3. Verificar a seguinte condição lógica:
#    - se **idade < 18** **ou** **estudante é verdadeiro**, então o cliente tem direito à meia-entrada .
# 4. Se a condição for satisfeita, exibir a mensagem: **"Meia-entrada aplicada."**
# 5. Caso contrário, exibir a mensagem: **"Valor integral."**
# #
# Com isso, o sistema cobre as duas situações previstas na regra de negócio e toma
# uma decisão automática a partir da combinação de condições booleanas .

# %% [markdown]
# ### algoritmo em pseudocódigo
# ```
#  Início
#    ler idade
#    ler estudante (verdadeiro/falso ou sim/não)
#
#    se (idade < 18) ou (estudante é verdadeiro) então
#        exibir "Meia-entrada aplicada."
#    senão
#        exibir "Valor integral."
#  Fim
#  ```

# %%
# Exemplo em Python inspirado no algoritmo do desafio

idade = int(input("Informe a idade do cliente: "))
resposta_estudante = input("O cliente é estudante? (s/n): ").strip().lower()

estudante = resposta_estudante == "s"

if idade < 18 or estudante:
    mensagem = "Meia-entrada aplicada."
else:
    mensagem = "Valor integral."

print(mensagem)
# Out:
# Informe a idade do cliente: 47
# O cliente é estudante? (s/n): s
# Meia-entrada aplicada.

# %% [markdown]
# ### Comentário sobre o desafio
#
#  Esse desafio é um bom exercício de **expressões lógicas com operadores relacionais
#  e booleanos**, pois combina duas condições diferentes em uma única verificação
#  usando o operador **OU** . Situações como essa são comuns em sistemas reais,
#  onde regras de negócio envolvem faixas de idade, status do usuário e outros critérios
#  que precisam ser avaliados automaticamente para tomar decisões consistentes .

# %% [markdown]
# ## Desafio: Calculando valor da entrega
# #
# Você está desenvolvendo um sistema para uma empresa de delivery. O valor da taxa de entrega
# depende da distância até o cliente e se o pedido foi feito em um dia de chuva.
# #
# Regras:
# - Até 5 km: taxa de R$ 5,00.
# - Entre 5 e 10 km: taxa de R$ 8,00.
# - Acima de 10 km: taxa de R$ 10,00.
# - Se estiver chovendo, acrescentar R$ 2,00 à taxa padrão.
# #
# O objetivo é criar um algoritmo em linguagem natural que informe o valor final da entrega,
# seguindo essas regras.

# %% [markdown]
# ### Solução em linguagem natural
# #
# **1. Entrada**
# - Solicitar a distância até o endereço do cliente (em km).
# - Perguntar se está chovendo (resposta booleana: verdadeiro/falso ou sim/não).
# #
# **2. Processamento**
# - Verificar a distância informada e definir a taxa base:
#   - Se a distância for menor ou igual a 5 km, taxa base = R$ 5,00.
#
#   - Se a distância for maior que 5 km e menor ou igual a 10 km, taxa base = R$ 8,00.
#
#   - Se a distância for maior que 10 km, taxa base = R$ 10,00.
#
# - Verificar se está chovendo:
#
#   - Se estiver chovendo, somar R$ 2,00 à taxa base.
#
# - Calcular o valor final da entrega a partir da taxa base (com ou sem acréscimo).
# #
# **3. Saída**
# - Exibir o valor total da taxa de entrega com uma mensagem clara, por exemplo:
#   - "Taxa de entrega: R$ X,00".

# %% [markdown]
# ### Exemplo de algoritmo em pseudocódigo
#
# ```
#  Início
#    ler distancia_km
#    ler chovendo (verdadeiro/falso ou sim/não)
#
#    se distancia_km ≤ 5 então
#        taxa_base ← 5
#    senão se distancia_km ≤ 10 então
#        taxa_base ← 8
#    senão
#        taxa_base ← 10
#
#    se chovendo é verdadeiro então
#        taxa_final ← taxa_base + 2
#    senão
#        taxa_final ← taxa_base
#
#    exibir "Taxa de entrega: R$ ", taxa_final
#  Fim
#  ```

# %%
# Exemplo em Python inspirado no algoritmo do desafio

distancia_km = float(input("Informe a distância até o cliente (em km): "))
resposta_chuva = input("Está chovendo? (s/n): ").strip().lower()

chovendo = resposta_chuva == "s"

if distancia_km <= 5:
    taxa_base = 5.00
elif distancia_km <= 10:
    taxa_base = 8.00
else:
    taxa_base = 10.00

if chovendo:
    taxa_final = taxa_base + 2.00
else:
    taxa_final = taxa_base

print(f"Taxa de entrega: R$ {taxa_final:.2f}")
# Out:
# Informe a distância até o cliente (em km): 10
# Está chovendo? (s/n): n
# Taxa de entrega: R$ 8.00

# %% [markdown]
# ###  Comentário sobre o desafio
#
#  Esse desafio combina **condicionais encadeadas** com uma verificação booleana adicional,
#  mostrando como regras de negócio reais podem depender tanto de valores numéricos
#  (distância em km) quanto de condições lógicas simples (está chovendo ou não).
#  A estrutura em etapas de **entrada → processamento → saída** ajuda a deixar o algoritmo
#  mais organizado e mais fácil de implementar em qualquer linguagem de programação.

# %% [markdown]
# ## Desafio: conversor de moedas
# #
# Você está desenvolvendo um sistema de apoio para uma agência de viagens.
# Uma das funcionalidades mais solicitadas é um conversor de moedas: o usuário
# informa um valor em reais `(R$)` e o sistema precisa mostrar quanto isso representa
# em dólares `(US$)`, usando uma taxa de câmbio definida pela empresa.
# #
# A tarefa é criar um algoritmo em linguagem natural que use uma **função** para fazer
# essa conversão. A função deve receber o valor em reais e a taxa de câmbio como entrada,
# e retornar o valor convertido.

# %% [markdown]
# ### Solução em linguagem natural
# #
# 1. Definir uma função chamada `converter_para_dolar` que receba dois parâmetros:
#    - `valor_em_reais`
#    - `taxa_de_cambio`.
# #
# 2. Dentro da função, calcular o valor convertido usando a fórmula:
#    - `valor_convertido = valor_em_reais / taxa_de_cambio`.
# #
# 3. A função deve **retornar** o `valor_convertido` para ser usado no restante do programa.
# #
# 4. No programa principal:
#    - Solicitar ao usuário o valor em reais que deseja converter.
#    - Solicitar a taxa de câmbio atual definida pela empresa.
#    - Chamar a função `converter_para_dolar` passando esses dois valores.
#    - Exibir o resultado com uma mensagem do tipo:
#      - "Com a taxa atual, o valor em dólares é: [valor]".
# #
# Essa abordagem organiza o código em um bloco reutilizável (a função), o que facilita
# futuras alterações, como adicionar novas moedas ou ajustar a fórmula de conversão.

# %% [markdown]
# ### Exemplo de algoritmo em pseudocódigo
# ```
#  Função converter_para_dolar(valor_em_reais, taxa_de_cambio)
#    valor_convertido ← valor_em_reais / taxa_de_cambio
#    retornar valor_convertido
#
#  Início (programa principal)
#    ler valor_em_reais
#    ler taxa_de_cambio
#    resultado ← converter_para_dolar(valor_em_reais, taxa_de_cambio)
#    exibir "Com a taxa atual, o valor em dólares é: ", resultado
#  Fim
#  ```

# %%
# Exemplo em Python inspirado no algoritmo do desafio

def converter_para_dolar(valor_em_reais, taxa_de_cambio):
    return valor_em_reais / taxa_de_cambio

valor_em_reais = float(input("Informe o valor em reais (R$): "))
taxa_de_cambio = float(input("Informe a taxa de câmbio (R$ por US$): "))

valor_convertido = converter_para_dolar(valor_em_reais, taxa_de_cambio)

print(f"Com a taxa atual, o valor em dólares é: US$ {valor_convertido:.2f}")
# Out:
# Informe o valor em reais (R$): 15
# Informe a taxa de câmbio (R$ por US$): 5.5
# Com a taxa atual, o valor em dólares é: US$ 2.73

# %% [markdown]
# ### Comentário sobre o desafio
# #
# Esse desafio reforça o uso de **funções** para encapsular um cálculo específico no caso, a conversão de reais para dólares com base em uma taxa de câmbio.
# Ao separar a lógica em uma função `converter_para_dolar`, o código fica mais organizado,
# reutilizável e fácil de evoluir, por exemplo, para incluir outras moedas ou diferentes
# regras de conversão no futuro.

# %% [markdown]
# ## Desafio: Simulador de pedidos em uma cafeteria
# #
# Você foi contratado por uma cafeteria que deseja automatizar o atendimento no balcão.
# O sistema deve permitir que o atendente registre os pedidos de cada cliente, calcule
# o valor total e aplique um **desconto de 10% para clientes cadastrados**.
# #
# O processo funciona assim:
# - O atendente informa quantos itens o cliente vai pedir.
# - Para cada item, o sistema solicita o nome e o preço.
# - Ao final, o sistema pergunta se o cliente é cadastrado.
# - Se for, aplica o desconto e exibe o valor com desconto.
# - Caso contrário, exibe o valor cheio.
# #
# O desafio é criar um algoritmo que represente essa lógica de forma completa.

# %% [markdown]
# ### Solução
#
# **1. Entrada**
# - Pedir a quantidade de itens que o cliente vai pedir.
# - Criar uma variável `total` iniciando em 0.
# - Para cada item:
#   - Solicitar o nome do item.
#   - Solicitar o preço do item.
#   - Somar o preço do item ao `total`.
# #
# **2. Processamento**
# - Ao final da leitura dos itens, perguntar se o cliente é cadastrado
#   (pode ser `True/False` ou “sim/não”).
# - Se o cliente for cadastrado:
#   - Calcular `desconto = total * 0.10`.
#   - Calcular `total_final = total - desconto`.
# - Senão:
#   - `total_final = total`.
# #
# **3. Saída**
# - Exibir o valor total a ser pago pelo cliente, deixando claro se houve desconto
#   ou se o valor é cheio.

# %% [markdown]
# ### Exemplo de algoritmo em pseudocódigo
# ```
#  Início
#    ler quantidade_itens
#    total ← 0
#
#    para i de 1 até quantidade_itens faça
#        ler nome_item
#        ler preco_item
#        total ← total + preco_item
#    fim-para
#
#    ler cliente_cadastrado (verdadeiro/falso ou sim/não)
#
#    se cliente_cadastrado é verdadeiro então
#        desconto ← total * 0.10
#        total_final ← total - desconto
#    senão
#        total_final ← total
#
#    exibir "Valor total a pagar: R$ ", total_final
#  Fim
#  ```

# %%
# Exemplo em Python inspirado no algoritmo do desafio

quantidade_itens = int(input("Quantos itens o cliente vai pedir? "))

total = 0.0

for i in range(1, quantidade_itens + 1):
    nome_item = input(f"Nome do item {i}: ")
    preco_item = float(input(f"Preço de '{nome_item}': R$ "))
    total += preco_item

resposta_cadastrado = input("O cliente é cadastrado? (s/n): ").strip().lower()
cliente_cadastrado = resposta_cadastrado == "s"

if cliente_cadastrado:
    desconto = total * 0.10
    total_final = total - desconto
else:
    desconto = 0.0
    total_final = total

print(f"\nTotal dos itens: R$ {total:.2f}")
print(f"Desconto aplicado: R$ {desconto:.2f}")
print(f"Valor final a pagar: R$ {total_final:.2f}")
# Out:
# Quantos itens o cliente vai pedir? 5
# Nome do item 1: café expresso
# Preço de 'café expresso': R$ 8
# Nome do item 2: torrada
# Preço de 'torrada': R$ 10
# Nome do item 3: chocolate quente
# Preço de 'chocolate quente': R$ 15
# Nome do item 4: café com leite
# Preço de 'café com leite': R$ 10
# Nome do item 5: pão na chapa
# Preço de 'pão na chapa': R$ 10
# O cliente é cadastrado? (s/n): s
#
# Total dos itens: R$ 53.00
# Desconto aplicado: R$ 5.30
# Valor final a pagar: R$ 47.70

# %% [markdown]
# ### Comentário sobre o desafio
# #
# Esse desafio integra vários conceitos trabalhados no curso: entrada de dados em laço
# (vários itens), acumulação de total, uso de condição booleana para clientes cadastrados
# e cálculo de desconto proporcional ao valor do pedido. Ele se aproxima bastante
# de um cenário real de sistemas de caixa, mostrando como algoritmos simples podem apoiar
# diretamente processos de atendimento.

# %% [markdown]
# # parei aqui

# %% [markdown]
# ## 🤖 Curso 2: IA: explorando o potencial da IA Generativa
# **⏱️ 8h** | **📊 Avaliação: 9,4** | **🎯 100% concluído**

# %% [markdown]
# ### ✍️ Prompts utilizados nas atividades "Mão na massa"

# %% [markdown]
# ## Mão na massa: criando um post para seu trabalho
# #
# Nesta atividade, a proposta é aplicar técnicas de engenharia de prompt para criar
# um post sobre um tema da minha área de trabalho ou estudo, em formato adequado para
# publicação no LinkedIn e com a hashtag **#IAnaAlura**.
# #
# Como estou trabalhando e estudando temas ligados a tecnologia, dados e inteligência artificial,
# decidi criar uma versão mais prática da atividade usando **Python no Colab**, estruturando
# o prompt em múltiplas etapas para gerar um post de forma organizada e reutilizável.

# %% [markdown]
# ### Tema escolhido
# #
# **Como Python e IA generativa podem aumentar a produtividade no desenvolvimento de soluções de dados e automação**.
# #
# Escolhi esse tema porque ele está alinhado com minha área de estudo e atuação,
# além de permitir explorar o uso de prompts bem estruturados para gerar conteúdo profissional
# de forma prática.

# %% [markdown]
# ### Prompt estruturado
# #
# Abaixo está o prompt em múltiplos passos, seguindo a proposta da atividade:
# #
# 1. Explique como Python pode ser usado junto com IA generativa para automatizar tarefas,
# análise de dados e geração de conteúdo técnico.
# #
# 2. Liste 5 aplicações práticas dessa combinação no contexto profissional de tecnologia.
# #
# 3. Gere 3 versões diferentes de um post para LinkedIn sobre esse tema.
# #
# 4. Compare as 3 versões e escolha a melhor, justificando a escolha com base em clareza,
# tom profissional e potencial de engajamento.
# #
# 5. Reescreva a versão final em um formato pronto para publicação no LinkedIn pessoal,
# com linguagem natural, tom profissional e a hashtag **#IAnaAlura**.

# %% [markdown]
# ### Configuração da API do Gemini
# #
# No Colab, estou usando o `userdata` para buscar a variável `GEMINI_API_KEY`.
#
# Antes de rodar, certifique-se de ter definido a chave em:
# `Configurações > User secrets > GEMINI_API_KEY`.

# %%
import google.generativeai as genai
from google.colab import userdata

api_key = userdata.get("GEMINI_API_KEY")

if not api_key:
    print("ATENÇÃO: a variável secreta GEMINI_API_KEY não está definida.")
    print("Defina-a em Configurações > User secrets antes de continuar.")
else:
    genai.configure(api_key=api_key)
    print("API do Gemini configurada com sucesso.")
# Out:
# API do Gemini configurada com sucesso.

# %% [markdown]
# ### Definindo o tema e o prompt estruturado

# %%
# Estruturando o prompt em Python para uso no Colab

tema = "Como Python e IA generativa podem aumentar a produtividade no desenvolvimento de soluções de dados e automação"

prompt = f"""
Você é um assistente especializado em criação de conteúdo profissional para LinkedIn.

Tarefa:
Crie um post para LinkedIn sobre o tema: "{tema}".

Siga estes passos:
1. Explique como Python pode ser usado junto com IA generativa para automatizar tarefas,
   análise de dados e geração de conteúdo técnico.
2. Liste 5 aplicações práticas dessa combinação no contexto profissional de tecnologia.
3. Gere 3 versões diferentes de um post para LinkedIn sobre esse tema.
4. Compare as 3 versões e escolha a melhor, justificando a escolha com base em clareza,
   tom profissional e potencial de engajamento.
5. Reescreva a melhor versão em formato final, pronta para publicação no LinkedIn.
6. Inclua obrigatoriamente a hashtag #IAnaAlura no final.

Regras:
- O texto deve ser profissional, natural e objetivo.
- O post deve ser adequado para o LinkedIn pessoal.
- Evite exageros e frases genéricas.
- Valorize aprendizado prático, produtividade e aplicação no mundo real.
"""

print(prompt)
# Out:
# Você é um assistente especializado em criação de conteúdo profissional para LinkedIn.
#
# Tarefa:
# Crie um post para LinkedIn sobre o tema: "Como Python e IA generativa podem aumentar a produtividade no desenvolvimento de soluções de dados e automação".
#
# Siga estes passos:
# 1. Explique como Python pode ser usado junto com IA generativa para automatizar tarefas,
#    análise de dados e geração de conteúdo técnico.
# 2. Liste 5 aplicações práticas dessa combinação no contexto profissional de tecnologia.
# 3. Gere 3 versões diferentes de um post para LinkedIn sobre esse tema.
# 4. Compare as 3 versões e escolha a melhor, justificando a escolha com base em clareza,
#    tom profissional e potencial de engajamento.
# 5. Reescreva a melhor versão em formato final, pronta para publicação no LinkedIn.
# 6. Inclua obrigatoriamente a hashtag #IAnaAlura no final.
#
# Regras:
# - O texto deve ser profissional, natural e objetivo.
# - O post deve ser adequado para o LinkedIn pessoal.
# ...

# %% [markdown]
# ### Gerando o conteúdo com o Gemini

# %%
if not api_key:
    print("Sem chave de API: pule esta célula até configurar GEMINI_API_KEY.")
else:
    model = genai.GenerativeModel("gemini-2.5-flash")

    try:
        response = model.generate_content(prompt)
        print("\n--- Conteúdo gerado pelo Gemini ---\n")
        print(response.text)
    except Exception as e:
        print(f"Ocorreu um erro ao gerar o conteúdo com o Gemini: {e}")
        print("Verifique se a API Key está correta e se o serviço está disponível.")

# %% [markdown]
# --- Conteúdo Gerado pelo Gemini ---
#
# Com certeza! Como seu assistente especializado em conteúdo para LinkedIn, preparei o material conforme solicitado.
#
# ---
#
# ### **1. Explicação: Como Python e IA Generativa aumentam a produtividade**
#
# Python, com seu vasto ecossistema de bibliotecas para dados (Pandas, NumPy, Scikit-learn) e sua capacidade de integrar-se a APIs, é a linguagem ideal para orquestrar soluções de dados e automação. Quando combinado com o poder da IA Generativa, especialmente Large Language Models (LLMs), ele se torna um catalisador de produtividade, permitindo a automação inteligente de tarefas que antes exigiam raciocínio humano e criatividade.
#
# A sinergia funciona assim:
# *   **Python como Orquestrador:** Ele gerencia o fluxo de dados, pré-processa as informações, envia prompts estruturados para as APIs dos LLMs e, em seguida, processa e integra as respostas geradas.
# *   **IA Generativa como "Cérebro" Inteligente:** Os LLMs podem gerar código, resumir grandes volumes de texto, extrair insights complexos, criar dados sintéticos e até mesmo gerar documentação técnica, tudo com base nas instruções de Python.
#
# Essa combinação permite automatizar não apenas a execução de tarefas repetitivas, mas também o "pensamento" por trás delas, acelerando o ciclo de desenvolvimento, otimizando a análise de dados e liberando equipes para focar em desafios mais estratégicos.
#
# ---
#
# ### **2. 5 Aplicações Práticas dessa Combinação no Contexto Profissional de Tecnologia**
#
# 1.  **Geração Automatizada de Código e Scripts:** Utilizar LLMs, orquestrados por Python, para criar trechos de código (SQL queries complexas, scripts ETL, funções de análise de dados) a partir de descrições em linguagem natural, acelerando o desenvolvimento e reduzindo erros.
# 2.  **Criação Inteligente de Documentação Técnica:** Automatizar a geração de documentação de APIs, guias de usuário, relatórios técnicos e especificações de sistemas, com Python extraindo informações e LLMs formatando o conteúdo de forma clara e concisa.
# 3.  **Análise e Sumarização de Dados Não Estruturados em Larga Escala:** Processar logs, e-mails, feedback de clientes ou documentos regulatórios, utilizando LLMs via Python para extrair insights chave, identificar sentimentos, tendências e gerar resumos executivos de forma eficiente.
# 4.  **Geração de Dados Sintéticos para Testes e Treinamento:** Criar datasets sintéticos realistas e representativos com Python e LLMs, para testar modelos de machine learning e sistemas de dados, garantindo privacidade e superando a escassez de dados reais.
# 5.  **Automação de Insights em Pipelines de Dados:** Integrar LLMs diretamente em pipelines de dados orquestrados por Python para identificar automaticamente anomalias, enriquecer dados textuais (ex: categorização, extração de entidades) ou gerar relatórios em tempo real sobre a saúde e performance dos dados.
#
# ---
#
# ### **3. 3 Versões Diferentes de um Post para LinkedIn**
#
# #### **Versão 1: Direta e Focada em Produtividade**
#
# **Gancho:** Python + IA Generativa: A Dupla Explosiva para sua Produtividade em Dados! 🚀
#
# **Corpo:**
# Cansado de tarefas repetitivas no desenvolvimento de soluções de dados e automação? A combinação de Python com IA Generativa (LLMs) está transformando a forma como trabalhamos, permitindo um salto massivo em produtividade e eficiência.
#
# Python, com sua flexibilidade e ecossistema robusto, atua como orquestrador, enquanto a IA Generativa adiciona inteligência para automatizar tarefas complexas, analisar dados de forma inovadora e gerar conteúdo técnico com agilidade.
#
# Imagine:
# 1.  **Geração Automatizada de Código/Scripts:** Crie SQL queries ou scripts ETL a partir de descrições simples.
# 2.  **Documentação Técnica Inteligente:** Gere documentação de APIs e sistemas automaticamente.
# 3.  **Análise Avançada de Dados Não Estruturados:** Extraia insights e resumos de logs, e-mails e feedback de clientes em segundos.
# 4.  **Criação de Dados Sintéticos:** Produza datasets realistas para testes e treinamento com segurança.
# 5.  **Automação de Insights em Pipelines:** Incorpore inteligência em seus pipelines para detecção de anomalias e enriquecimento de dados.
#
# Essa sinergia libera sua equipe para focar em desafios estratégicos, entregando valor mais rapidamente.
#
# **Chamada para Ação:** Qual dessas aplicações você acha mais promissora para o seu dia a dia? Compartilhe sua opinião!
# `#Python #IAGenerativa #Produtividade #DesenvolvimentoDeDados #Automação`
#
# ---
#
# #### **Versão 2: Narrativa com Desafio/Solução**
#
# **Gancho:** Desafios em Dados e Automação? Python e IA Generativa são a sua Resposta para Produtividade!
#
# **Corpo:**
# No ritmo acelerado do desenvolvimento de soluções de dados e automação, a complexidade e a repetição podem se tornar gargalos significativos. Mas e se houvesse uma forma de superar esses desafios, otimizando fluxos de trabalho e impulsionando a inovação com inteligência?
#
# A resposta está na poderosa combinação de **Python e IA Generativa**. Python, como nosso versátil ecossistema para dados, agora pode interagir com Large Language Models (LLMs) para delegar tarefas intelectuais complexas. Essa sinergia transforma a automação de scripts, a análise de dados e a geração de conteúdo técnico.
#
# Como essa parceria funciona na prática para aumentar sua produtividade:
# *   **Geração Automatizada de Código:** Crie SQL queries, scripts ETL ou funções de análise de dados com base em descrições em linguagem natural.
# *   **Documentação Técnica Inteligente:** Gere documentação de APIs, guias de usuário e relatórios de forma automatizada e precisa.
# *   **Análise de Dados Não Estruturados em Escala:** Extraia insights chave, sentimentos e tendências de logs, e-mails ou feedback de clientes em segundos.
# *   **Criação de Dados Sintéticos Seguros:** Produza datasets realistas para testar modelos e sistemas de dados, garantindo privacidade.
# *   **Automação de Insights em Pipelines:** Integre LLMs em seus pipelines para identificar anomalias, enriquecer dados ou gerar relatórios em tempo real.
#
# Essa abordagem não apenas economiza tempo, mas eleva a qualidade, a inovação e a capacidade de resposta das suas soluções.
#
# **Chamada para Ação:** Você já explorou essa combinação? Conte-nos como Python e IA Generativa têm impactado seus projetos e fluxos de trabalho!
# `#DataScience #MachineLearning #PythonTips #Eficiência #Inovação`
#
# ---
#
# #### **Versão 3: Curiosa e Voltada para o Futuro**
#
# **Gancho:** O futuro da engenharia de dados e automação já começou – e ele fala Python com sotaque de IA Generativa! 💡
#
# **Corpo:**
# Estamos à beira de uma revolução na forma como construímos soluções de dados e sistemas de automação. A união de Python, a linguagem universal para dados, com o poder transformador da IA Generativa está redefinindo os limites da produtividade e da criatividade tecnológica.
#
# Imagine um cenário onde tarefas que hoje consomem horas de trabalho manual se tornam automatizadas e inteligentes. Python orquestra a magia, interagindo com LLMs para gerar, analisar e otimizar, liberando desenvolvedores para focar em inovação estratégica.
#
# Conheça 5 aplicações que já são realidade:
# 1.  **Desenvolvimento de Código Acelerado:** Geração inteligente de funções, classes e scripts com base em prompts.
# 2.  **Documentação Ágil e Precisa:** Criar e manter documentação técnica atualizada sem atrito.
# 3.  **Mineração de Insights de Conteúdo:** Extrair valor profundo de documentos, logs e conversas em tempo recorde.
# 4.  **Dados para Teste sem Complicações:** Geração sob demanda de dados sintéticos para cobertura de testes robusta.
# 5.  **Monitoramento e Otimização Inteligente de Dados:** Pipelines que se auto-aperfeiçoam com a ajuda de IA para qualidade e desempenho.
#
# É tempo de abraçar essa nova era e capacitar-se para o futuro do desenvolvimento.
#
# **Chamada para Ação:** Como você vê o impacto dessa tendência no seu crescimento profissional? Deixe seu comentário!
# `#FutureOfTech #AI #DataEngineering #Automation #CareerGrowth`
#
# ---
#
# ### **4. Comparação das 3 Versões e Escolha da Melhor**
#
# **Análise:**
#
# *   **Versão 1 (Direta e Focada em Produtividade):** É clara e concisa. O gancho com emoji pode ser um pouco informal para alguns públicos do LinkedIn, mas a lista de aplicações é muito eficaz. A chamada para ação é simples e direta.
# *   **Versão 2 (Narrativa com Desafio/Solução):** Excelente em clareza, pois contextualiza a necessidade da solução antes de apresentá-la. O tom é profissional, abordando uma "dor" comum no mercado (complexidade e repetição). A chamada para ação é mais convidativa e incentiva o compartilhamento de experiências.
# *   **Versão 3 (Curiosa e Voltada para o Futuro):** O gancho é instigante e o tom é visionário. No entanto, a linguagem "sotaque de IA Generativa" pode soar um pouco informal, e o início é um pouco mais abstrato antes de chegar às aplicações práticas. A CTA é boa para engajamento em desenvolvimento de carreira.
#
# **Escolha da Melhor Versão:**
#
# A **Versão 2** é a melhor opção.
#
# **Justificativa:**
#
# *   **Clareza:** A estrutura de problema-solução é inerentemente clara e fácil de seguir. Ela primeiro estabelece um desafio comum que muitos profissionais de tecnologia enfrentam, e então apresenta a combinação de Python e IA Generativa como a solução prática e inovadora. Isso ajuda o leitor a compreender o valor rapidamente.
# *   **Tom Profissional:** Mantém um tom muito profissional sem ser excessivamente formal ou abstrato. Aborda uma "dor" real do mercado de forma direta e concisa, ressoando com o público profissional do LinkedIn.
# *   **Potencial de Engajamento:** Ao começar com um desafio que muitos desenvolvedores e engenheiros de dados enfrentam ("Cansado de tarefas repetitivas?"), a postagem imediatamente cria uma conexão com o leitor. A chamada para ação ("Você já explorou essa combinação? Conte-nos como Python e IA Generativa têm impactado seus projetos e fluxos de trabalho!") é excelente, pois convida à partilha de experiências reais, fomentando uma discussão valiosa. A lista de aplicações práticas é apresentada de forma organizada e fácil de consumir.
#
# ---
#
# ### **5. Reescreva a melhor versão em formato final, pronta para publicação no LinkedIn.**
#
# ---
#
# **Desafios em Dados e Automação? Python e IA Generativa são a sua Resposta para Produtividade!**
#
# No ritmo acelerado do desenvolvimento de soluções de dados e automação, a complexidade e a repetição podem se tornar gargalos significativos. Mas e se houvesse uma forma de superar esses desafios, otimizando fluxos de trabalho e impulsionando a inovação com inteligência?
#
# A resposta está na poderosa combinação de **Python e IA Generativa**. Python, como nosso versátil ecossistema para dados, agora pode interagir com Large Language Models (LLMs) para delegar tarefas intelectuais complexas. Essa sinergia transforma a automação de scripts, a análise de dados e a geração de conteúdo técnico, elevando a produtividade a um novo patamar.
#
# Como essa parceria funciona na prática para aumentar sua produtividade:
# *   **Geração Automatizada de Código:** Crie SQL queries, scripts ETL ou funções de análise de dados com base em descrições em linguagem natural.
# *   **Documentação Técnica Inteligente:** Gere documentação de APIs, guias de usuário e relatórios de forma automatizada e precisa.
# *   **Análise de Dados Não Estruturados em Escala:** Extraia insights chave, sentimentos e tendências de logs, e-mails ou feedback de clientes em segundos.
# *   **Criação de Dados Sintéticos Seguros:** Produza datasets realistas para testar modelos e sistemas de dados, garantindo privacidade.
# *   **Automação de Insights em Pipelines:** Integre LLMs em seus pipelines para identificar anomalias, enriquecer dados ou gerar relatórios em tempo real.
#
# Essa abordagem não apenas economiza tempo, mas eleva a qualidade, a inovação e a capacidade de resposta das suas soluções.
#
# Você já explorou essa combinação? Conte-nos como Python e IA Generativa têm impactado seus projetos e fluxos de trabalho!
#
# `#Python #IAGenerativa #Produtividade #DesenvolvimentoDeDados #Automação #DataScience #EngenhariaDeDados #Inovação #IAnaAlura`

# %% [markdown]
# ### Conclusão pessoal – Engenharia de prompt na prática
# #
# Nesta atividade, consegui sair da teoria de engenharia de prompt e levar o conceito para um fluxo
# bem mais próximo do meu dia a dia técnico. Em vez de apenas escrever um prompt isolado, estruturei
# um roteiro de múltiplos passos e implementei tudo em Python no Colab, conectando com a API do Gemini
# para gerar um post completo para LinkedIn.
# #
# Trabalhar o prompt dessa forma, com subtarefas claras, contexto detalhado, regras explícitas e
# pedido de comparação entre respostas, mostrou na prática o quanto pequenos ajustes nas instruções
# mudam a qualidade do resultado. Ao encapsular isso em código, percebi que a engenharia de prompt
# deixa de ser só “conversar com a IA” e passa a ser uma parte integrada do desenvolvimento, algo que
# posso versionar, reutilizar e evoluir como qualquer outro componente de software.

# %% [markdown]
# ## Mão na massa: analisando planilha com Python + Gemini
# #
# Nesta atividade, decidi ir além da proposta original: em vez de apenas enviar a planilha
# para uma IA multimodal, montei um fluxo completo no Colab usando Python e Gemini API.
# #
# A ideia é combinar:
# - **Python/pandas** para leitura confiável dos dados e cálculo das médias;
# - **matplotlib** para geração do gráfico;
# - **Gemini** para análise textual e interpretação dos dados;
# - **arquivos salvos** para manter evidências do estudo e consulta futura.

# %% [markdown]
# ### Instalação e importação das bibliotecas

# %%
# !pip -q install google-generativeai pandas matplotlib

import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import google.generativeai as genai
from google.colab import userdata
from datetime import datetime

# %% [markdown]
# ### Configuração da API do Gemini

# %%
api_key = userdata.get("GEMINI_API_KEY")

if not api_key:
    raise ValueError("GEMINI_API_KEY não encontrada em User secrets do Colab.")

genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-2.5-flash")

print("Gemini configurado com sucesso.")
# Out:
# Gemini configurado com sucesso.

# %% [markdown]
# ### Carregando a planilha CSV
# #
# A planilha é a disponibilizada pela atividade da Alura.

# %%
url_csv = "https://raw.githubusercontent.com/lucasyudy/imersao-digital-2026-santander/main/semana-1/data/M%C3%A9dia%20de%20notas.csv"
df = pd.read_csv(url_csv, sep=",", encoding='latin-1')

display(df.head())
print(df.dtypes)
# Out:
#                    Aluno  Prova 1  Prova 2  Prova 3  Prova 4  Nota final
# 0        Marcelo Barbosa      6.5      8.3      9.2      7.2         NaN
# 1         Rafaela Santos      8.3      4.5      7.5      4.5         NaN
# 2         Ronaldo Santos      7.0      2.1      8.9      8.9         NaN
# 3  Lucas Gabriel Ribeiro      5.9      9.8      6.4      6.1         NaN
# 4         Luana da Silva      9.2      5.6      3.1      9.8         NaN
# Aluno          object
# Prova 1       float64
# Prova 2       float64
# Prova 3       float64
# Prova 4       float64
# Nota final    float64
# dtype: object

# %% [markdown]
# ### Identificando colunas numéricas e calculando a média dos alunos
# #
# Conforme o enunciado, o objetivo é calcular a média aritmética das notas de cada estudante.

# %%
colunas_notas = ['Prova 1', 'Prova 2', 'Prova 3', 'Prova 4'] # Identificando explicitamente as colunas de notas
print("Colunas de notas para cálculo da média:", colunas_notas)

df["media_aritmetica"] = df[colunas_notas].mean(axis=1)

display(df.head())
# Out:
# Colunas de notas para cálculo da média: ['Prova 1', 'Prova 2', 'Prova 3', 'Prova 4']
#                    Aluno  Prova 1  Prova 2  Prova 3  Prova 4  Nota final  \
# 0        Marcelo Barbosa      6.5      8.3      9.2      7.2         NaN
# 1         Rafaela Santos      8.3      4.5      7.5      4.5         NaN
# 2         Ronaldo Santos      7.0      2.1      8.9      8.9         NaN
# 3  Lucas Gabriel Ribeiro      5.9      9.8      6.4      6.1         NaN
# 4         Luana da Silva      9.2      5.6      3.1      9.8         NaN
#
#    media_aritmetica
# 0             7.800
# 1             6.200
# 2             6.725
# 3             7.050
# 4             6.925

# %% [markdown]
# ### Verificando o tamanho do dataset e os valores nulos

# %%
print(f"Tamanho do DataFrame (linhas, colunas): {df.shape}")
print("\nQuantidade de valores nulos por coluna:")
print(df.isnull().sum())
# Out:
# Tamanho do DataFrame (linhas, colunas): (999, 7)
#
# Quantidade de valores nulos por coluna:
# Aluno               979
# Prova 1             979
# Prova 2             979
# Prova 3             979
# Prova 4             979
# Nota final          999
# media_aritmetica    979
# dtype: int64

# %% [markdown]
# ### Removendo apenas as linhas onde "Aluno" estão nulas.

# %%
df.dropna(subset=['Aluno'] + colunas_notas, inplace=True)
display(df.head())
print(f"Nova forma do DataFrame: {df.shape}")
# Out:
#                    Aluno  Prova 1  Prova 2  Prova 3  Prova 4  Nota final  \
# 0        Marcelo Barbosa      6.5      8.3      9.2      7.2         NaN
# 1         Rafaela Santos      8.3      4.5      7.5      4.5         NaN
# 2         Ronaldo Santos      7.0      2.1      8.9      8.9         NaN
# 3  Lucas Gabriel Ribeiro      5.9      9.8      6.4      6.1         NaN
# 4         Luana da Silva      9.2      5.6      3.1      9.8         NaN
#
#    media_aritmetica
# 0             7.800
# 1             6.200
# 2             6.725
# 3             7.050
# 4             6.925
# Nova forma do DataFrame: (20, 7)

# %% [markdown]
# ### Exibindo a média de cada aluno

# %%
possiveis_nomes = [c for c in df.columns if "nome" in c.lower() or "aluno" in c.lower()]

if possiveis_nomes:
    coluna_nome = possiveis_nomes[0]
    resultado_medias = df[[coluna_nome, "media_aritmetica"]].copy()
else:
    resultado_medias = df[["media_aritmetica"]].copy()

display(resultado_medias)
# Out:
#                       Aluno  media_aritmetica
# 0           Marcelo Barbosa             7.800
# 1            Rafaela Santos             6.200
# 2            Ronaldo Santos             6.725
# 3     Lucas Gabriel Ribeiro             7.050
# 4            Luana da Silva             6.925
# 5           Mariana Pereira             4.275
# 6      Maria Eduarda Farias             7.675
# 7   Fernando Henrique Silva             6.250
# 8      Pedro Henrique Souza             6.325
# 9        Ana Paula Oliveira             3.925
# 10        Natália Guimarães             4.750
# 11      João Vitor Ferreira             4.925
# 12          Rodrigo Almeida             5.975
# 13         Gustavo Carvalho             6.850
# 14            Leticia Costa             7.025
# 15           Aline da Rocha             6.600
# 16     Marcos Vinicius Lima             5.725
# 17    Carla Cristina Castro             3.050
# 18         Isabela da Costa             6.425
# ...

# %% [markdown]
# ### Gerando gráfico de dispersão das médias
# #
# O enunciado sugere, por exemplo, um gráfico de dispersão das médias dos estudantes.

# %%
plt.figure(figsize=(10, 5))
plt.scatter(range(len(df)), df["media_aritmetica"], color="royalblue")
plt.title("Dispersão das médias dos estudantes")
plt.xlabel("Índice do estudante")
plt.ylabel("Média aritmética")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Salvando o gráfico e o CSV com as médias
# #
# Isso ajuda a manter um registro do estudo e permite comprovar a atividade futuramente.

# %%
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

arquivo_csv_saida = f"medias_estudantes_{timestamp}.csv"
arquivo_grafico_saida = f"grafico_medias_{timestamp}.png"

resultado_medias.to_csv(arquivo_csv_saida, index=False)

plt.figure(figsize=(10, 5))
plt.scatter(range(len(df)), df["media_aritmetica"], color="royalblue")
plt.title("Dispersão das médias dos estudantes")
plt.xlabel("Índice do estudante")
plt.ylabel("Média aritmética")
plt.grid(alpha=0.3)
plt.savefig(arquivo_grafico_saida, dpi=150, bbox_inches="tight")
plt.show()

print("Arquivos salvos:")
print("-", arquivo_csv_saida)
print("-", arquivo_grafico_saida)
# Out:
# Arquivos salvos:
# - medias_estudantes_2026-05-14_05-08-30.csv
# - grafico_medias_2026-05-14_05-08-30.png

# %% [markdown]
# ### Pedindo ao Gemini uma análise da planilha e dos resultados
# #
# Aqui uso a IA como assistente de interpretação, não como única fonte de cálculo,
# o que é mais seguro e mais alinhado à recomendação do instrutor.

# %%
amostra_dados = df.head(20).to_csv(index=False)

prompt_analise = f"""
Você é um assistente de análise de dados educacionais.

A seguir está uma amostra de uma planilha CSV contendo notas de estudantes.
Quero que você:
1. Descreva que tipos de dados a planilha parece conter.
2. Explique o que representam as colunas numéricas.
3. Comente o significado da média aritmética calculada para cada aluno.
4. Sugira 3 interpretações úteis que um professor poderia tirar desses dados.
5. Escreva a resposta em português do Brasil, de forma clara e objetiva.

Amostra da planilha:
{amostra_dados}

Informação adicional:
Foi criada uma coluna chamada 'media_aritmetica' com a média das colunas numéricas de cada aluno.
"""

response = model.generate_content(prompt_analise)
analise_textual = response.text

print(analise_textual)
# Out:
# Olá! Como seu assistente de análise de dados educacionais, fiz uma análise da amostra da planilha fornecida.
#
# ---
#
# ### Análise da Planilha de Notas de Estudantes
#
# **1. Tipos de dados na planilha:**
#
# A planilha contém principalmente dois tipos de dados:
# *   **Texto (String):** Representado pela coluna "Aluno", que armazena os nomes completos dos estudantes.
# *   **Numérico (Float/Decimal):** Representado pelas colunas "Prova 1", "Prova 2", "Prova 3", "Prova 4" e "media_aritmetica". Estes dados são valores decimais que indicam pontuações ou notas. A coluna "Nota final" está atualmente vazia, mas seu nome sugere que deveria conter dados numéricos (uma nota consolidada).
#
# **2. O que representam as colunas numéricas:**
#
# ...

# %% [markdown]
# ---
#
# ### Análise da Planilha de Notas de Estudantes
#
# **1. Tipos de dados na planilha:**
#
# A planilha contém principalmente dois tipos de dados:
# *   **Texto (String):** Representado pela coluna "Aluno", que armazena os nomes completos dos estudantes.
# *   **Numérico (Float/Decimal):** Representado pelas colunas "Prova 1", "Prova 2", "Prova 3", "Prova 4" e "media_aritmetica". Estes dados são valores decimais que indicam pontuações ou notas. A coluna "Nota final" está atualmente vazia, mas seu nome sugere que deveria conter dados numéricos (uma nota consolidada).
#
# **2. O que representam as colunas numéricas:**
#
# *   **Prova 1, Prova 2, Prova 3, Prova 4:** Representam as notas individuais obtidas por cada aluno em quatro avaliações distintas ao longo de um período (por exemplo, um semestre ou bimestre). São medidas pontuais do desempenho do aluno em diferentes momentos ou conteúdos.
# *   **Nota final:** Esta coluna está vazia na amostra, mas, pelo nome, sugere que seria a nota consolidada ou final do aluno na disciplina, que poderia ser calculada a partir das notas das provas e, possivelmente, de outros critérios (participação, trabalhos, etc.), muitas vezes com pesos diferentes.
# *   **media_aritmetica:** Esta coluna representa a média aritmética simples das notas das quatro provas ("Prova 1" a "Prova 4") para cada aluno. É uma medida de tendência central que busca resumir o desempenho geral do aluno nessas quatro avaliações, assumindo que todas têm o mesmo peso.
#
# **3. Significado da média aritmética calculada para cada aluno:**
#
# A "media_aritmetica" calculada para cada aluno oferece um valor único que resume o desempenho geral desse estudante nas quatro avaliações. Ela indica o "nível médio" de pontuação que o aluno alcançou nessas provas.
#
# *   **Pontos chave:**
#     *   **Resumo de desempenho:** É um indicador rápido do nível de sucesso do aluno nas avaliações.
#     *   **Comparação:** Permite comparar o desempenho médio de um aluno com o de outros, ou com critérios de aprovação (se houver uma média mínima).
#     *   **Visão geral:** Ajuda o professor a ter uma ideia geral se o aluno está se saindo bem, de forma consistente ou não, assumindo que todas as provas têm igual importância.
#     *   **Limitação:** É importante notar que a média aritmética, por si só, não mostra a consistência do desempenho. Um aluno pode ter uma média alta com notas muito variáveis (ex: 10, 10, 0, 0), enquanto outro pode ter a mesma média com notas consistentes (ex: 5, 5, 5, 5). Para isso, seria necessário analisar as notas individuais de cada prova.
#
# **4. 3 interpretações úteis que um professor poderia tirar desses dados:**
#
# 1.  **Identificação de Alunos em Risco ou de Alta Performance:** Ao ordenar os dados pela coluna "media_aritmetica", o professor pode identificar rapidamente quais alunos estão com as menores médias (potencialmente em risco de reprovação e necessitando de intervenção) e quais estão com as maiores médias (demonstrando excelente domínio do conteúdo). Por exemplo, **Ana Paula Oliveira (3.925)** tem a menor média, indicando uma necessidade urgente de atenção, enquanto **Marcelo Barbosa (7.8)** é um dos que têm o melhor desempenho.
#
# 2.  **Análise de Dificuldades em Tópicos Específicos ou Formatos de Avaliação:** Observando as notas em cada "Prova X" individualmente para a turma toda, o professor pode identificar se houve um padrão de baixo desempenho em uma prova específica. Se a "Prova 2" apresentar muitas notas baixas para a maioria dos alunos (como **Rafaela Santos (4.5), Ronaldo Santos (2.1), Luana da Silva (5.6), Mariana Pereira (1.2), Pedro Henrique Souza (3.4), Ana Paula Oliveira (0.5), etc.**), isso pode indicar que o conteúdo abordado nessa prova foi particularmente difícil para a turma, que a metodologia de ensino para aquele tópico não foi eficaz, ou que a própria prova estava mal formulada.
#
# 3.  **Avaliação da Consistência do Desempenho Individual:** Ao analisar as notas de cada prova para um aluno específico, o professor pode identificar a consistência ou a variação do desempenho. Um aluno como **Rafaela Santos (8.3, 4.5, 7.5, 4.5)** mostra notas oscilantes, o que pode indicar falta de estudo contínuo, problemas de atenção em certas avaliações ou dificuldades pontuais. Por outro lado, **Maria Eduarda Farias (8.8, 7.7, 4.2, 10.0)** tem uma variação significativa, sugerindo que ela pode ter tido um problema específico na Prova 3 ou que certos tópicos são mais desafiadores para ela, apesar de um desempenho geral forte. Isso ajuda o professor a entender melhor as necessidades individuais de aprendizado e a oferecer feedback mais direcionado.

# %% [markdown]
# ### Salvando a análise textual gerada pelo Gemini

# %%
arquivo_analise = f"analise_gemini_{timestamp}.txt"

with open(arquivo_analise, "w", encoding="utf-8") as f:
    f.write(analise_textual)

print("Análise salva em:", arquivo_analise)
# Out:
# Análise salva em: analise_gemini_2026-05-14_05-08-30.txt

# %% [markdown]
# ### Conclusão
# #
# Nesta atividade, optei por combinar IA e programação de forma complementar. Usei Python
# para garantir o cálculo confiável das médias e a geração do gráfico, e utilizei o Gemini
# como apoio para interpretar e explicar os dados de maneira mais contextualizada.
# #
# Essa abordagem me parece mais madura e útil para o aprendizado, porque não delega tudo à IA:
# ela participa como assistente, enquanto o processamento principal permanece verificável,
# reproduzível e documentado no próprio notebook.

# %% [markdown]
# ---
#
# **Prompt 3 — Google Gemini: Resumindo documentos:**
# '''Resuma o conteúdo deste texto em 3 tópicos principais e destaque os pontos mais relevantes:
# [cole aqui]'''

# %% [markdown]
# ---
#
# **Prompt 4 — DALL-E / Bing Images: Completando post com imagens:**
# '''Gere uma imagem de_facomida saudável eque seja fresca e e gourmet,el estilo e fotografico, comu bemramomo ecamera e bemramoluz --ar 16:9'''

# %% [markdown]
# ## 🛠️ Ferramentas utilizadas nesta semana
#
# | Ferramenta | Uso prático |
# |---|---|
# | ChatGPT | Criação de texto e revisão de conteúdo |
# | Google Gemini | Resumo e análise de documentos |
# | Maritaca AI | Análise de textos longos |
# | Bing Images / DALL-E | Geração de imagens para posts |
#
# ---
#
# ## 🔗 Links do curso
#
# - [Curso: Pensamento Computacional](https://cursos.alura.com.br/course/computacao-fundamentos-computacao-pensamento-computacional)
# - [Curso: IA Generativa](https://cursos.alura.com.br/course/ia-explorando-potencial-inteligencia-artificial-generativa)
# - [Trilha completa no GitHub](https://github.com/lucasyudy/imersao-digital-2026-santander/tree/main/semana-1)
